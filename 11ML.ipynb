# %% [markdown]
# ## Machine Learning Pipeline
# - Data Collection/Generation
# - Data Cleaning/Feature Engineering
# - Algorithms To find interesting pattern
# - Deployment

# %% [markdown]
# ## Supervised ML
# - Data is labelled
# - Either regression or classification
# ![image.png](attachment:4180805f-21f5-453c-bd03-229a8d897cc3.png)
#
# - Algorithm used is linear regression, logistic,SVM,Neural
# - Eg-Spam Detection,Document Classification,NLP,Image Classification etc

# %% [markdown]
# ## Unsupervised Learning
# - No supervision
# - Grouping similar data points
# - no labelled data

# %% [markdown]
# ## Semi- Supervised learning
# - we dont have labelled data but we manually labelled some data using ruled based labelling. Usinf this we classify our another data.Eg-10 millions tweets, object segmentation, similarity detection, automatic labelling.
#
# ## Reinforcement learning
# - Agent
# - Environment
# - Actions
# - State
# - goal
#
# - A reinforcement learning agent is able to perceive and interpret its environment, take actions and learn through trial and error. It is about taking suitable action to maximize reward in a particular situation.
